# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import scipy.stats as stats

# houses my function to connect to Codeup DB
import wrangle as w

# %%
df = w.get_zillow_data()
# Out:
# creating df and exporting csv

# %% [markdown]
# - Shapiro test to check if its normally distributed
# - Check "which stats test to do" slide to find out which stat's test to do
# - If sample size is between 30 and 500 don't automatically assume normal distribution
# - Spearman vs pearsons both for continuous but one is for parametric and the other is for nonparametric
# - Clustering allows us to create a engineer a feature that maybe a realized feature between data points
# - Line 43 on how to add mean line to both charts produced

# %%
df.head()
# Out:
#         id  parcelid  airconditioningtypeid  architecturalstyletypeid  \
# 0  1727539  14297519                    NaN                       NaN
# 1  1387261  17052889                    NaN                       NaN
# 2    11677  14186244                    NaN                       NaN
# 3  2288172  12177905                    NaN                       NaN
# 4   781532  12095076                    1.0                       NaN
#
#    basementsqft  bathroomcnt  bedroomcnt buildingclasstypeid  \
# 0           NaN          3.5         4.0                None
# 1           NaN          1.0         2.0                None
# 2           NaN          2.0         3.0                None
# 3           NaN          3.0         4.0                None
# 4           NaN          3.0         4.0                None
#
#    buildingqualitytypeid  calculatedbathnbr  ...  censustractandblock  \
# 0                    NaN                3.5  ...         6.059063e+13
# ...

# %%
df.shape
# Out:
# (52319, 68)
